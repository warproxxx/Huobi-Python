# %%
from live_trader import liveTrading

# %%
lt = liveTrading('huobi_swap', symbol='BTC-USD', testnet=False)

# %%
lt.set_position()

# %%
lt.fill_order('buy', 'now')
# Out:
# Time at filling order is: 2020-11-15 20:09:31.945105
# Sending market buy order for BTC-USD of size 3 on huobi_swap in 2020-11-15 20:09:32.162888

# %%
lt.add_stop_loss()
# Out:
# {'status': 'ok',
#  'data': {'order_id': 7002240, 'order_id_str': '7002240'},
#  'ts': 1605450310740}

# %%
lt.fill_order('sell', 'now')
# Out:
# Time at filling order is: 2020-11-15 20:10:22.737383
# Sending market sell order for BTC-USD of size 3 on huobi_swap in 2020-11-15 20:10:23.467814

# %%
lt.fill_order('buy', 'attempt_limit')
# Out:
# Time at filling order is: 2020-11-15 20:04:21.097239
# Sending limit buy order for BTC-USD of size 3 @ 16043.8 on huobi_swap in 2020-11-15 20:04:21.825338
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# Best Bid is 16043.9 and Best Ask is 16043.8
# ...

# %%
lt.fill_order('sell', 'attempt_limit')
# Out:
# Time at filling order is: 2020-11-15 20:08:47.847823
# Sending limit sell order for BTC-USD of size 3 @ 16108.6 on huobi_swap in 2020-11-15 20:08:48.576750
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16108.6 and Best Ask is 16108.5
# Best Bid is 16104.1 and Best Ask is 16104.0
# Current price is much better, closing to open new one
# Sending limit sell order for BTC-USD of size 3 @ 16104.1 on huobi_swap in 2020-11-15 20:09:01.383210
# Best Bid is 16100.1 and Best Ask is 16100.0
# Current price is much better, closing to open new one
# Sending limit sell order for BTC-USD of size 3 @ 16100.1 on huobi_swap in 2020-11-15 20:09:04.251752
# ...
